# %%
import pandas as pd
import numpy as np

# %%
con_df = pd.read_csv('./Condominium_comparable_rental_income.csv')
grn_df = pd.read_csv('./Greenthumb_Community_Gardens.csv')

# %%
con_df.head()
# Out:
#   MANHATTAN CONDOMINIUM PROPERTY Boro-Block-Lot  \
# 0                                  1-00007-7501
# 1                                  1-00008-7501
# 2                                  1-00015-7502
# 3                                  1-00016-7501
# 4                                  1-00016-7502
#
#   MANHATTAN CONDOMINIUM PROPERTY Condo Section  \
# 0                                       735-R1
# 1                                      1822-R1
# 2                                      1557-R1
# 3                                       308-R1
# 4                                       313-R1
#
#   MANHATTAN CONDOMINIUM PROPERTY Address  Borough  Postcode   Latitude  \
# 0                        1 COENTIES SLIP        1   10004.0  40.703627
# 1                    39 WHITEHALL STREET        1   10004.0  40.703037
# 2                         20 WEST STREET        1   10004.0  40.706358
# 3                       377 RECTOR PLACE        1   10280.0  40.709506
# 4                      320 ALBANY STREET        1   10280.0  40.710165
#
#    Longitude  Community Board  Council District  Census Tract  \
# 0 -74.010607              1.0               1.0           9.0
# 1 -74.012969              1.0               1.0           9.0
# 2 -74.016151              1.0               1.0          13.0
# 3 -74.018002              1.0               1.0       31704.0
# 4 -74.016751              1.0               1.0       31704.0
#
#                        ...                        \
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#    COMPARABLE RENTAL 2  Neighborhood  \
# 0                          FINANCIAL
# 1                       CIVIC CENTER
# 2                          FINANCIAL
# 3                            TRIBECA
# 4                            TRIBECA
#
#    COMPARABLE RENTAL 2  Building Classification  \
# 0                                   D8-ELEVATOR
# 1                                   D6-ELEVATOR
# 2                                   D5-ELEVATOR
# 3                                   D8-ELEVATOR
# 4                                   D8-ELEVATOR
#
#   COMPARABLE RENTAL 2  Total Units COMPARABLE RENTAL 2  Year Built  \
# 0                             61.0                          1929.0
# 1                            151.0                          1999.0
# 2                            482.0                          1929.0
# 3                            218.0                          1998.0
# 4                            218.0                          1998.0
#
#   COMPARABLE RENTAL 2  Gross SqFt  COMPARABLE RENTAL 2  Est. Gross Income  \
# 0                         57941.0                               2260000.0
# 1                        139697.0                               7168000.0
# 2                        390531.0                              17218000.0
# 3                        239185.0                              15723000.0
# 4                        239185.0                              15723000.0
#
#    COMPARABLE RENTAL 2  Gross Income per SqFt  \
# 0                                        39.0
# 1                                        51.0
# 2                                        44.1
# 3                                        66.0
# 4                                        66.0
#
#    COMPARABLE RENTAL 2  Full Market Value  \
# 0                              11100000.0
# 1                              35200000.0
# 2                              84500000.0
# 3                              77200000.0
# 4                              77200000.0
#
#    COMPARABLE RENTAL 2  Market Value per SqFt  \
# 0                                       192.0
# 1                                       252.0
# 2                                       216.0
# 3                                       323.0
# 4                                       323.0
#
#    COMPARABLE RENTAL 2  Dist. from Coop in miles
# 0                                           0.40
# 1                                           1.05
# 2                                           0.40
# 3                                           0.00
# 4                                           0.00
#
# [5 rows x 46 columns]

# %%
con_df['NTA'].head(20)

# %%
grn_df['NTA'].head(20)
# Out:
# 0     Lower East Side                               ...
# 2     East Harlem South                             ...
# 3     East Harlem North                             ...
# 4     East Village                                  ...
# 6     East Tremont                                  ...
# 8     Lower East Side                               ...
# 9     Park Slope-Gowanus                            ...
# 11    Lower East Side                               ...
# 12    East Village                                  ...
# 13    Ocean Hill                                    ...
# 14    Melrose South-Mott Haven North                ...
# 15    North Corona                                  ...
# 16    Lower East Side                               ...
# 18    Morrisania-Melrose                            ...
# 20    Brownsville                                   ...
# 22    East Village                                  ...
# 23    Bedford                                       ...
# 24    Lower East Side                               ...
# 25    Carroll Gardens-Columbia Street-Red Hook      ...
# 26    Brownsville                                   ...
# Name: NTA, dtype: object

# %% [markdown]
# ## Mapping

# %%
import folium
from IPython.display import HTML

def display(m, height=300):
    """Takes a folium instance and embed HTML."""
    m._build_map()
    srcdoc = m.HTML.replace('"', '&quot;')
    embed = HTML('<iframe srcdoc="{0}" '
                 'style="width: 100%; height: {1}px; '
                 'border: none"></iframe>'.format(srcdoc, height))
    return embed

# %%
grn_df['Latitude'] = grn_df['Latitude'].astype(float)
grn_df['Longitude'] = grn_df['Longitude'].astype(float)
grn_df = grn_df.dropna(axis=0, subset=['Latitude','Longitude'])

# %%
con_df['Latitude'] = con_df['Latitude'].astype(float)
con_df['Longitude'] = con_df['Longitude'].astype(float)
con_df = con_df.dropna(axis=0, subset=['Latitude','Longitude'])

# %%
con_df['Latitude'].describe()['count']
# Out:
# 1148.0

# %%
map_1 = folium.Map(location=[40.773752, -73.972679], zoom_start = 12) ## ["Stamen Terrain", "Stamen Toner", "Mapbox Bright"]

other_points = int(con_df['Longitude'].describe()['count'])
green_points = int(grn_df['Longitude'].describe()['count'])


for i in range(other_points):
    # Other areas   
    latitude = con_df.iloc[i]['Latitude']
    longitude = con_df.iloc[i]['Longitude']
    
    folium.CircleMarker([latitude, longitude],
                        radius=2,
                        color='#FF0000',
                        fill_color='#FF0000', ).add_to(map_1)


## green areas  
for i in range(green_points):
    latitude = grn_df.iloc[i]['Latitude']
    longitude = grn_df.iloc[i]['Longitude']
    
    folium.CircleMarker([latitude, longitude],
                        radius=2,
                        color='#008000',
                        fill_color='#008000', ).add_to(map_1)
    
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
